# %%
#server
# git clone https://github.com/ultralytics/yolov5
# cd yolov5
# pip install -qr requirements.txt

#colab
# !git clone https://github.com/ultralytics/yolov5
# %cd yolov5
# %pip install -qr requirements.txt
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 12228, done.
# remote: Counting objects: 100% (33/33), done.
# remote: Compressing objects: 100% (25/25), done.
# remote: Total 12228 (delta 15), reused 20 (delta 8), pack-reused 12195
# Receiving objects: 100% (12228/12228), 11.98 MiB | 29.41 MiB/s, done.
# Resolving deltas: 100% (8459/8459), done.
# /content/yolov5
#      |████████████████████████████████| 596 kB 4.9 MB/s

# %%
#server
# python3 detect.py --weights /home/ubuntu/ai/best.pt --img 640 --conf 0.1 --source /home/ubuntu/img/picam/ --project=/home/ubuntu/img/health --name=img

#colab
# !python detect.py --weights /content/best.pt --img 640 --conf 0.1 --source /content/test1.jpg --project=/content/results --name=img
# Out:
# detect: weights=['/content/best.pt'], source=/content/test1.jpg, data=data/coco128.yaml, imgsz=[640, 640], conf_thres=0.1, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=/content/results, name=img, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5 🚀 v6.1-250-g6adc53b Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 290 layers, 20856975 parameters, 0 gradients, 48.0 GFLOPs
# image 1/1 /content/test1.jpg: 640x480 1 healthy, 1 unhealthy, Done. (0.025s)
# Speed: 0.7ms pre-process, 24.7ms inference, 37.4ms NMS per image at shape (1, 3, 640, 640)
# Results saved to /content/results/img

# %%
from IPython.core.display import Image
from PIL import Image
import torch
import pandas as pd

model = torch.hub.load('ultralytics/yolov5', 'custom', '/content/best.pt')  # custom trained model

# Images
im = '/content/test1.jpg'  # or file, Path, URL, PIL, OpenCV, numpy, list

#Resize
im = Image.open(im)
im = im.resize((640,640))

# Inference
results = model(im)

# Results image
results.print()

# Results text
result = results.pandas().xyxy[0]
img_result = result['name']
img_result = pd.DataFrame(img_result)
img_result.value_counts()

img_val = pd.DataFrame(img_result.value_counts())
img_val = img_val.transpose()
img_result_2 = img_result['name'].str.slice(start=0, stop=2)

if len(img_val.columns) > 1:
    if img_result_2[0] == 'un':
        print('Your plants are unhealthy.')
    elif img_result_2[1] == 'un':
        print('Your plants are unhealthy.')
    else:
        print('Your plants are healthy.')
else:
     if img_result_2[0] == 'un':
        print('Your plants are unhealthy.')
     else:
         print('Your plants are healthy.')
# Out:
# Using cache found in /root/.cache/torch/hub/ultralytics_yolov5_master
# requirements: PyYAML>=5.3.1 not found and is required by YOLOv5, attempting auto-update...
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#
# requirements: 1 package updated per /root/.cache/torch/hub/ultralytics_yolov5_master/requirements.txt
# requirements: ⚠️ Restart runtime or rerun command for updates to take effect
#
# YOLOv5 🚀 2022-6-10 Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# Model summary: 290 layers, 20856975 parameters, 0 gradients
# Adding AutoShape...
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:590: UserWarning: Metadata Warning, tag 282 had too many entries: 2, expected 1
#   % (tag, len(values))
# /usr/local/lib/python3.7/dist-packages/PIL/TiffImagePlugin.py:590: UserWarning: Metadata Warning, tag 283 had too many entries: 2, expected 1
#   % (tag, len(values))
# ...
